# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
p1 = [(1, 7), (3.7, 4), (5, 3), (-88, 0)]
p2 = [(2, 2), (17, 0)]
p3 = [(7, 4), (6, 3), (-1, 2), (43, 0)]
p4 = [(1, 4)]
p5 = [(1, 2)]
p6 = [(1, 3)]
lista = [p1, p2, p3, p4, p5, p6]

def criaPol ():
    res = []
    n = int(input("Introduza o número de termos do seu polinómio"))
    i = 0
    while n > 0:
        coef = float(input("Introduza o coeficiente do termo" + str(i)))
        exp = int(input("Introduza o expoente do termo" + str(i)))
        res.append((coef, exp))
        n = n - 1
        i= i + 1
    return res

def guardarPolinomios(listap, fnome):
    ficheiroPol = open(fnome, "w")
    for pol in listap:
        for monomio in pol:
            coef, exp = monomio
            ficheiroPol.write(str(coef) + "," + str(exp) + "|")
        ficheiroPol.write("\n")
    ficheiroPol.close()
    return

guardarPolinomios(lista, "listapolinomios.txt")

def recuperarPol(fnome):
    res = []
    ficheiroPol = open(fnome)
    for linha in ficheiroPol:
        polinomio =linha[:-1]
        termos = polinomio.split("|")
        for t in termos:
            monomio = t.split(",")
            coef = float(monomio[0])
            exp = int(monomio[1])
            res.append((coef, exp))
    ficheiroPol.close()
    return res

recuperarPol("listapolinomios.txt")

def calcPolinomio(p, x):
    res = 0
    for termo in p:
        coef, exp = termo
        res = res + (x**exp) * coef     
    return res

def verPolinomio(p):
    res = ""
    for monomio in p:
        coef, exp = monomio
        if coef < 0:
            res = res + str(coef) 
        else:
            res = res + "+" + str(coef) 
        if exp != 0:
            res = res + "x^" + str(exp) + " "
    return res
def grauPolinomio(p):
    res = 0
    for termo in p:
        coef, grau = termo
        if grau > res:
            res = grau
    return res 


def listarOrdem (fnome):
    print("Ordem         Polinómio")
    print("-----------------------")
    for p in fnome:
        print()


def listarGrau():

def maiorPol ():

def calcDerivada(pol):
   derivada = []
    for coef, exp in pol:
        if exp > 0:
            derivada.append((coef * exp, exp - 1))
    return derivada

def mostrarDerivda(fnome):
    print("Polinómio          Derivada")
    print("---------------------------")


def somaPol(fnome):
    n = int(input("Introduza a ordem dos polinómios que quer somar"))
    res = []
    for pol in fnome:


def graficoPol():

# %%
#Menu:

def menu():
    print("============MENU============")
    print("(1) Criar Polinómio\n(2) Ler lista de polinómios de um ficheiro\n(3) Listar polinómios\n(4) Calcular valor do polinómio num ponto\n(5) Listar polinómios com grau\n(6) Maior grau\n(7) Derivada\n(8) Somar 2 polinómios\n(9) Gerar gráfico de 1 polinómio\n(10) Gravar polinómios num ficheiro\n(11) Sair da aplicação ")
    print("============================")
    n = int(input("Introduza um número entre 0 e 9"))
    return n


ni = menu()
while ni < 11:
    if ni == 1:
        print(criaPol())
        print("\n")
    elif ni == 2:
        print(recuperarPol("listapolinomios.txt"))
        print("\n")
    elif ni == 3:
        print(listarOrdem("listapolinomios.txt"))
        print("\n")
    elif ni == 4:
        x1 = float(input("Introduza o valor para o cálculo do polinómio"))
        print(calcPolinomio(p, x1))
        print("\n")
    elif ni == 5:
        print(listarGrau())
        print("\n")
    elif ni == 6:
        print(maiorPol())
        print("\n")
    elif ni == 7:
        print(mostrarDerivda())
        print("\n")
    elif ni == 8:
        print(somaPol())
        print("\n")
    elif ni == 9:
        print(graficoPol())
        print("\n")
    elif ni == 10:
        print(guardarPolinomios(criaPol, "listapolinomios.txt"))
        print("\n")

    ni = menu()
print("Obrigada por usar este menu!! :)")
